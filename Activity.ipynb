# %% [markdown]
# <a href="https://colab.research.google.com/github/Preciousdisono/Keziah_IS3/blob/main/Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Preciousdisono/Keziah_IS3/refs/heads/main/student%20performace.csv')

# %%
df.head(50)
# Out:
#     Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0               7               99                        NaN            3
# 1               4               82                         No            4
# 2               8               51                        Yes            7
# 3               5               52                        NaN            5
# 4               7               75                         No            1
# 5               3               78                         No            9
# 6               7               73                        Yes            5
# 7               8               45                        NaN            4
# 8               5               77                         No            8
# 9               4               89                         No            4
# 10              8               91                         No            4
# ...

# %%
df_filna = df.fillna('N/A')

# %%
df_filna.head(50)
# Out:
#     Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0               7               99                        N/A            3
# 1               4               82                         No            4
# 2               8               51                        Yes            7
# 3               5               52                        N/A            5
# 4               7               75                         No            1
# 5               3               78                         No            9
# 6               7               73                        Yes            5
# 7               8               45                        N/A            4
# 8               5               77                         No            8
# 9               4               89                         No            4
# 10              8               91                         No            4
# ...

# %%
(df.isnull().sum())
# Out:
# Hours Studied                        0
# Previous Scores                      0
# Extracurricular Activities          11
# Sleep Hours                          0
# Sample Question Papers Practiced     0
# Performance Index                    0
# dtype: int64

# %%
df = df.drop(columns=['Extracurricular Activities'])

# %%
df.head(50)
# Out:
#     Hours Studied  Previous Scores  Sleep Hours  \
# 0               7               99            3
# 1               4               82            4
# 2               8               51            7
# 3               5               52            5
# 4               7               75            1
# 5               3               78            9
# 6               7               73            5
# 7               8               45            4
# 8               5               77            8
# 9               4               89            4
# 10              8               91            4
# 11              8               79            6
# 12              3               47            9
# 13              6               47            5
# 14              5               79            7
# 15              2               72            4
# 16              8               73            8
# 17              6               83            7
# ...
